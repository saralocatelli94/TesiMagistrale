# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import statistics
import math
import numpy as np
from scipy.stats import linregress
import datetime

# %%
mypath='C:/Users/sara/Documents/5anno/TESI/tracciati/ConversioneExcel'    
df = pd.read_csv( mypath+'/AE_12.06.1823.30.02512.csv', names=['time', 'spO2'])
spo2_array=df['spO2']
time_array=df['time']

# %%
plt.figure(figsize=(15,6))
plt.title('Plot spO2')
plt.axis([time_array[0],time_array[len(time_array)-1],70,100])
plt.step(time_array,spo2_array)

# %% [markdown]
# ### Preprocessing

# %%
#Outlier noise
str(datetime.timedelta(seconds=time_array[len(time_array)-1]))
index=df[df.spO2 == 0].index
#str(datetime.timedelta(seconds=time_array[58759]))
df=df.drop(df.index[index])  
df_outlier=pd.DataFrame()
df_outlier['time']=np.array(df['time'])
df_outlier['spO2']=np.array(df['spO2'])

# %%
plt.figure(figsize=(15,6))
plt.title('Plot spO2 without outlier noise')
time_array=df_outlier['time']
spo2_array=df_outlier['spO2']
plt.step(time_array,spo2_array)

# %%
# Fluctuation noise

# %% [markdown]
# ### Feature extraction

# %%
desaturations=pd.DataFrame()
pstart=[]
pvalley1=[]
pvalley2=[]
pstop=[]
plowest=[]
ptraslaction=[]
tdown=[]
tup=[]
tlast=[]
somma=0
for i in range(0,len(spo2_array)):
    somma=somma+spo2_array[i]
xbase=1/len(spo2_array)*somma-10
CASE=0
for i in range(0,len(spo2_array)-2):
    pv1=0
    pv2=0
    if(CASE==0 and spo2_array[i]>spo2_array[i+1] and spo2_array[i]>xbase):
        pstart.append(df_outlier['time'][i])
        pv1=i+1
        pv2=i+1
        CASE=1
    elif(CASE==1 and spo2_array[i]>spo2_array[i+1]):
        pv1+=1
        pv2+=1
    elif(CASE==1 and spo2_array[i]==spo2_array[i+1]): #sto salendo
        ptraslaction.append(i+1)
        CASE=2
    elif(CASE==2 and spo2_array[i]<spo2_array[i+1]):
        pstop.append(df_outlier['time'][i])
        CASE=0
desaturations['start']=pstart[0:len(pstart)-1]
desaturations['stop']=pstop

# %%
desaturations
# Out:
#         start      stop
# 0     85040.0   85046.0
# 1     85091.0   85096.0
# 2     85141.0   85148.0
# 3     85150.0   85168.0
# 4     85211.0   85228.0
# 5     85236.0   85252.0
# 6     85274.0   85294.0
# 7     85314.0   85324.0
# 8     85325.0   85343.0
# 9     85344.0   85345.0
# 10    85369.0   85375.0
# 11    85445.0   85470.0
# 12    85497.0   85528.0
# 13    85545.0   85549.0
# 14    85565.0   85574.0
# 15    85588.0   85592.0
# 16    85593.0   85594.0
# 17    85597.0   85619.0
# 18    85624.0   85627.0
# 19    85631.0   85666.0
# 20    85698.0   85715.0
# 21    85716.0   85747.0
# 22    85765.0   85805.0
# 23    85820.0   85860.0
# 24    85875.0   85950.0
# 25    85968.0   85996.0
# 26    86001.0   86033.0
# 27    86064.0   86074.0
# 28    86081.0   86100.0
# 29    86105.0   86133.0
# ..        ...       ...
# 471  108520.0  108540.0
# 472  108570.0  108600.0
# 473  108610.0  108640.0
# 474  108660.0  108700.0
# 475  108720.0  108740.0
# 476  108770.0  108790.0
# 477  108820.0  108860.0
# 478  108900.0  108970.0
# 479  108990.0  109000.0
# 480  109010.0  109010.0
# 481  109040.0  109060.0
# 482  109100.0  109100.0
# 483  109120.0  109150.0
# 484  109190.0  109200.0
# 485  109260.0  109340.0
# 486  109360.0  109380.0
# 487  109410.0  109430.0
# 488  109460.0  109530.0
# 489  109530.0  109530.0
# 490  109540.0  109540.0
# 491  109540.0  109560.0
# 492  109640.0  109650.0
# 493  109680.0  109710.0
# 494  109820.0  109840.0
# 495  109870.0  109880.0
# 496  109910.0  109960.0
# 497  109970.0  110160.0
# 498  110210.0  110250.0
# 499  110260.0  110310.0
# 500  110330.0  110380.0
#
# [501 rows x 2 columns]

# %%
len(pstart)
# Out:
# 502

# %%
len(pstop
   )
# Out:
# 501
